# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/Singh/Downloads/netflix1.csv")

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
# How many movies and TV-series are made in India?
df['country'].value_counts()['India']
# Out:
# 1057

# %%
# How many movies and TV-series are made in India and released in 2013?
df.loc[(df['country'] == 'India')]['release_year'].value_counts()[2013]
# Out:
# 62

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
sns.histplot(data=df['release_year'])
# Out:
# <AxesSubplot:xlabel='release_year', ylabel='Count'>

# %%
sns.countplot(df['listed_in'])
# Out:
# C:\Users\Singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='listed_in', ylabel='count'>

# %%
df['country'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Data Cleaning :

# %%
dfClean = df.copy()

# %%
#date_added column datatype should be 'datetime' instead of 'String'
dfClean.date_added = pd.to_datetime(dfClean.date_added)

# %%
dfClean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   datetime64[ns]
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 686.8+ KB

# %%
#'listed_in' column has multiple variables, so I have made 3 more categories to analyse it better
dfClean['listed_in1'] = 0
dfClean['listed_in2'] = 0
dfClean['listed_in3'] = 0
temp_cat = dfClean.listed_in.str.split(',')
i=0
for i in range (8790):
    t_cat = temp_cat[i]
    if len(t_cat) == 1:
        dfClean['listed_in1'][i] = temp_cat[i][0]
        dfClean['listed_in2'][i] = 0
        dfClean['listed_in3'][i] = 0
    if len(t_cat) == 2:
        dfClean['listed_in1'][i] = temp_cat[i][0]
        dfClean['listed_in2'][i] = temp_cat[i][1]
        dfClean['listed_in3'][i] = 0
    if len(t_cat) == 3:
        dfClean['listed_in1'][i] = temp_cat[i][0]
        dfClean['listed_in2'][i] = temp_cat[i][1]
        dfClean['listed_in3'][i] = temp_cat[i][2]
# Out:
# C:\Users\Singh\AppData\Local\Temp\ipykernel_13904\78745378.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClean['listed_in1'][i] = temp_cat[i][0]
# C:\Users\Singh\AppData\Local\Temp\ipykernel_13904\78745378.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClean['listed_in2'][i] = 0
# C:\Users\Singh\AppData\Local\Temp\ipykernel_13904\78745378.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
dfClean
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating   duration  \
# ...

# %%
# We observe that whole dataset is categorised into two types : 'TV Show' and 'Movie', so we have created seperate dataframe for both the types.

dfTv = dfClean[dfClean.type == 'TV Show']
dfMovie = dfClean[dfClean.type == 'Movie']

# %%
dfTv
# Out:
#      show_id     type                            title         director  \
# 1         s3  TV Show                        Ganglands  Julien Leclercq
# 2         s6  TV Show                    Midnight Mass    Mike Flanagan
# 5         s9  TV Show    The Great British Baking Show  Andy Devonshire
# 17        s4  TV Show            Jailbirds New Orleans        Not Given
# 18       s15  TV Show  Crime Stories: India Detectives        Not Given
# ...      ...      ...                              ...              ...
# 8785   s8797  TV Show                       Yunus Emre        Not Given
# 8786   s8798  TV Show                        Zak Storm        Not Given
# 8787   s8801  TV Show               Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                             Yoko        Not Given
# 8789   s8786  TV Show                              YOM        Not Given
#
#              country date_added  release_year rating   duration  \
# ...

# %%
dfMovie
# Out:
#      show_id   type                             title         director  \
# 0         s1  Movie              Dick Johnson Is Dead  Kirsten Johnson
# 3        s14  Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8  Movie                           Sankofa     Haile Gerima
# 6        s10  Movie                      The Starling   Theodore Melfi
# 7       s939  Movie   Motu Patlu in the Game of Zones      Suhas Kadav
# ...      ...    ...                               ...              ...
# 8702   s8232  Movie                          The Bund        Not Given
# 8707   s8269  Movie                  The Darkest Dawn        Not Given
# 8716   s8331  Movie                  The Great Battle        Not Given
# 8763   s8648  Movie       Twisted Trunk, Big Fat Body        Not Given
# 8783   s8785  Movie              Yoko and His Friends        Not Given
#
#              country date_added  release_year rating duration  \
# ...

# %%
# Since whole dataframe has two types : 'TV Show' and 'Movie', duration column is of type object but actually we should convert it's datatype to integer in case of Movies.

tempDur = dfMovie.duration.str.split(' ',expand=True)
dfMovie['duration_minutes'] = tempDur[0]
dfMovie.duration_minutes = pd.to_numeric(dfMovie.duration_minutes)
# Out:
# C:\Users\Singh\AppData\Local\Temp\ipykernel_13904\1415357893.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfMovie['duration_minutes'] = tempDur[0]
# C:\Users\Singh\AppData\Local\Temp\ipykernel_13904\1415357893.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfMovie.duration_minutes = pd.to_numeric(dfMovie.duration_minutes)

# %%
dfMovie
# Out:
#      show_id   type                             title         director  \
# 0         s1  Movie              Dick Johnson Is Dead  Kirsten Johnson
# 3        s14  Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8  Movie                           Sankofa     Haile Gerima
# 6        s10  Movie                      The Starling   Theodore Melfi
# 7       s939  Movie   Motu Patlu in the Game of Zones      Suhas Kadav
# ...      ...    ...                               ...              ...
# 8702   s8232  Movie                          The Bund        Not Given
# 8707   s8269  Movie                  The Darkest Dawn        Not Given
# 8716   s8331  Movie                  The Great Battle        Not Given
# 8763   s8648  Movie       Twisted Trunk, Big Fat Body        Not Given
# 8783   s8785  Movie              Yoko and His Friends        Not Given
#
#              country date_added  release_year rating duration  \
# ...

# %%
plt.figure(figsize=[20,10])
base_color = sns.color_palette('twilight_shifted',n_colors=5)
tvMovie = sns.countplot(x=dfClean.date_added.dt.year, data=dfClean, hue='type', palette = base_color)
tvMovie.set_title("No. of TV Shows and Movies Netflix has released per Year",fontsize = 25)
tvMovie.set_xlabel('Year',fontsize = 20)
tvMovie.set_ylabel('No. of Movies/TV Shows',fontsize = 20)
for container in tvMovie.containers:
    tvMovie.bar_label(container)

# %%
sort_order = dfTv.groupby('country').count().sort_values(by = 'show_id',ascending=False)[0:10].index
dfTv_c = dfTv[dfTv['country'].isin(sort_order)]
base_color = base_color = sns.color_palette()[0]
plt.figure(figsize=[20,10])
tv_c = sns.countplot(x='country',data=dfTv_c,order=sort_order, color = base_color)
tv_c.set_title("Number of TV Shows(Netflix) produced by Countries",fontsize = 20)
tv_c.set_xlabel('Country',fontsize = 15)
tv_c.set_ylabel('Number of TV Shows',fontsize = 15)
for container in tv_c.containers:
    tv_c.bar_label(container)

# %%
sort_order = dfMovie.groupby('country').count().sort_values(by = 'show_id',ascending=False)[0:10].index
dfMovie_c = dfMovie[dfMovie['country'].isin(sort_order)]
base_color = base_color = sns.color_palette()[0]
plt.figure(figsize=[20,10])
movie_c = sns.countplot(x='country',data=dfMovie_c,order=sort_order, color = base_color)
movie_c.set_title("Number of Movies(Netflix) produced by Country",fontsize = 20)
movie_c.set_xlabel('Country',fontsize = 15)
movie_c.set_ylabel('Number of Movies',fontsize = 15)
for container in movie_c.containers:
    movie_c.bar_label(container)

# %%
sort_order = dfMovie.groupby('director').count().sort_values(by = 'show_id',ascending=False)[0:5].index
dfMovie_c = dfMovie[dfMovie['director'].isin(sort_order)]
dfMovie_c['director'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='director'>

# %%
sns.distplot(dfMovie['duration_minutes'])
# Out:
# C:\Users\Singh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='duration_minutes', ylabel='Density'>

# %%
sns.boxplot(dfMovie['duration_minutes'])
# Out:
# C:\Users\Singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='duration_minutes'>

# %%
dfMovie['duration_minutes'].mean()
# Out:
# 99.58488410055502

# %%
sns.scatterplot(dfMovie['release_year'], dfMovie['duration_minutes'])
# Out:
# C:\Users\Singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='release_year', ylabel='duration_minutes'>

# %%
# Out:
# C:\Users\Singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='release_year'>

# %%
sort_order = dfMovie.groupby('country').count().sort_values(by = 'show_id',ascending=False)[0:10].index
dfMovie_c = dfMovie[dfMovie['country'].isin(sort_order)]
sns.barplot(dfMovie_c['country'], dfMovie_c['duration_minutes'])
# Out:
# C:\Users\Singh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='country', ylabel='duration_minutes'>

# %%
# Out:
# C:\Users\Singh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [50], in <cell line: 3>()
#       1 sort_order = dfMovie.groupby('country').count().sort_values(by = 'show_id',ascending=False)[0:10].index
#       2 dfMovie_c = dfMovie[dfMovie['country'].isin(sort_order)]
# ----> 3 sns.distplot(dfMovie_c['country'], dfMovie_c['duration_minutes'])
#
# ...

# %%
sns.heatmap(pd.crosstab(dfClean['country'], dfClean['release_year']))
# Out:
# <AxesSubplot:xlabel='release_year', ylabel='country'>
